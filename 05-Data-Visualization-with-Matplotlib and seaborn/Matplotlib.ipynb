# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x= np.linspace(0,10,25)
y=x*x+2
print(x)
print(y)
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]

# %%
plt.plot(x,y,'r')

# %%
plt.subplot(1,2,1) #row col index
plt.plot(x,y,'r--') 
plt.subplot(1,2,2)
plt.plot(y,x,'g*-')

# %%
plt.subplot(1,2,1) #row col index
plt.plot(x,y,'r--') 
plt.subplot(1,2,1)
plt.plot(y,x,'g*-')

# %%
fig = plt.figure()
axis = fig.add_axes([0.5,0.1,0.8,0.8]) #left bottom width height
axis.plot(x,y,'r')

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)
for ax in axes:
    ax.plot(x,y,'r')

# %%
fig= plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8]) #big canvas
axes2 = fig.add_axes([0.2,0.5,0.3,0.3]) #small canvas

axes1.plot(x,y,'r')
axes2.plot(y,x,'b')

# %%
fig = plt.figure(figsize=(16,9), dpi=300)
axis = fig.add_axes([0.5,0.1,0.8,0.8]) #left bottom width height
axis.plot(x,y,'r')

# %%
ax.legend(["label 1", "label 2"])
fig, axes = plt.subplots(dpi=150)

axes.set_xlabel("x-label")
axes.set_ylabel("y-label")
axes.set_title("title of graph")
axes.plot(x,x**2)
axes.plot(x,x**3)

axes.legend(["y=x**2","y=x**3"], loc=2)

# %%
#line color, transparency, and many more
fig, axes = plt.subplots(dpi=150)
axes.plot(x,x+1,color="red",alpha=0.5) #alpha = transparency
axes.plot(x,x+2, color="#1155dd")
axes.plot(x,x+3)

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x,x+1,color="blue", linewidth=0.25) #or use lw
axes.plot(x,x+2,color="blue",linewidth=1)
axes.plot(x,x+3,color="blue",linewidth=2)
axes.plot(x,x+4,color="blue",linewidth=2.5)

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x,x+1,color="blue", lw=2, linestyle='-')
axes.plot(x,x+2,color="blue",lw=2, linestyle='-.')
axes.plot(x,x+3,color="blue",lw=2, linestyle=':')

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x,x+1,color="blue", lw=2, linestyle='-')
axes.plot(x,x+2,color="blue",lw=2, linestyle='-.')
axes.plot(x,x+3,color="blue",lw=2, linestyle=':')

line, = axes.plot(x,x+4,color="black", lw=1.50)
line.set_dashes([5,10,15,10])

line, = axes.plot(x,x+5,color="black", lw=1.50)
line.set_dashes([5,10,15,3])

line, = axes.plot(x,x+6,color="black", lw=1.50)
line.set_dashes([5,10,30,30])

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x,x+1,color="blue",marker = "o" ) 
axes.plot(x,x+2,color="blue",marker = "s")
axes.plot(x,x+3,color="blue",marker = "+")
axes.plot(x,x+4,color="blue",marker="1")
axes.plot(x,x+6,color="blue",marker="o", markersize = 10)
axes.plot(x,x+6,color="blue",marker="o", markerfacecolor = "red")

# %%
#set canvas grid and axis range
fig, Axes=plt.subplots(1,2,figsize=(10,5))

Axes[0].plot(x,x**2,x,x**3,lw=2)
Axes[0].grid(True)

Axes[1].plot(x,x**2,x,x**3,lw=2)
Axes[1].set_ylim([0,60])
Axes[1].set_xlim([2,5])
Axes[1].grid(True)

# %% [markdown]
# #Other 2D Graphics

# %%
n=np.array([0,1,2,3,4,5])

fig, axes = plt.subplots(1,4,figsize=(16,5))
axes[0].set_title("Scatter")
axes[0].scatter(x,x+0.25*np.random.randn(len(x)))

axes[1].set_title("Step")
axes[1].step(n,n**2,lw=2)

axes[2].set_title("Bar")
axes[2].bar(n,n**2,align="center",alpha=0.5)

axes[3].set_title("fill between")
axes[3].fill_between(x,x**2,x**3,color="green",alpha=0.5)

# %%
#Draw a radar chart
fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0,0.0,.6,.6], polar=True)
t=np.linspace(0,2*np.pi,100)
ax.plot(t,t*2,color="blue",lw=3)

# %%
#histogram
n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].set_title("Default histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, cumulative=True, bins=8)
# Out:
# (array([6.9000e+01, 1.6140e+03, 1.4575e+04, 5.1671e+04, 8.6998e+04,
#         9.8663e+04, 9.9953e+04, 1.0000e+05]),
#  array([-4.31404843, -3.22691359, -2.13977875, -1.05264391,  0.03449093,
#          1.12162577,  2.20876061,  3.29589545,  4.38303029]),
#  <BarContainer object of 8 artists>)

# %%
# Draw contour image

import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
Z = (Z1 - Z2) * 2
print(X)
print(Y)
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# [[-2.    -2.    -2.    ... -2.    -2.    -2.   ]
#  [-1.975 -1.975 -1.975 ... -1.975 -1.975 -1.975]
#  [-1.95  -1.95  -1.95  ... -1.95  -1.95  -1.95 ]
#  ...
#  [ 1.925  1.925  1.925 ...  1.925  1.925  1.925]
#  [ 1.95   1.95   1.95  ...  1.95   1.95   1.95 ]
#  [ 1.975  1.975  1.975 ...  1.975  1.975  1.975]]

# %%
fig, ax= plt.subplots()
CS=ax.contour(X,Y,Z)
ax.clabel(CS,inline=1,fontsize=10)
ax.set_title("Contour Map")
# Out:
# Text(0.5, 1.0, 'Contour Map')

# %%
# Draw 3D surface image
from mpl_toolkits.mplot3d.axes3d import Axes3D

fig = plt.figure(figsize=(14, 6))

# Specify the 3D graphics to draw, with projection='3d'
ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)
